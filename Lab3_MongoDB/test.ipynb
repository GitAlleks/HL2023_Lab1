# %%
import pandas as pd

# %%
df = pd.read_csv('taxi_rides.csv')
df
# Out:
# /var/folders/nb/w_fjyjss51j0y5y1279bw9tr0000gn/T/ipykernel_5033/4070383598.py:1: DtypeWarning: Columns (12,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('taxi_rides.csv')
#          Unnamed: 0  driver_id  client_id             start_point  \
# 0                 0       3134        111   (51.62878, -0.172348)
# 1                 1       4068       1561  (51.551131, -0.173485)
# 2                 2       1314        526    (51.580247, -0.1188)
# 3                 3       2773        521  (51.546822, -0.442101)
# 4                 4       1978       1476  (51.566182, -0.137344)
# ...             ...        ...        ...                     ...
# 9999995     9999995        303         40  (51.611234, -0.423317)
# 9999996     9999996       1417       1085  (51.474597, -0.120644)
# 9999997     9999997       3399        395  (51.524137, -0.177031)
# 9999998     9999998       3293       1573  (51.652474, -0.107021)
# ...

# %%
df.count()
# Out:
# Unnamed: 0                  10000000
# driver_id                   10000000
# client_id                   10000000
# start_point                 10000000
# end_point                   10000000
# distance                    10000000
# start_time                  10000000
# end_time                    10000000
# road_time                   10000000
# cost                        10000000
# driver_rate                     5000
# client_rate                     5000
# category_driver_feedback        5000
# text_driver_feedback            5000
# category_client_feedback        5000
# text_client_feedback            5000
# dtype: int64
